# %% [markdown]
# You can download and run this notebook locally, or you can run it for free in a cloud environment using Colab or Sagemaker Studio Lab:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kirbyju/TCIA_Notebooks/blob/main/TCIA_REST_API_Complete_Documentation.ipynb)
#
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github.com/kirbyju/TCIA_Notebooks/blob/main/TCIA_REST_API_Complete_Documentation.ipynb)
#
# ### Set logging level to INFO in Google Colab (optional)
# This step should be skipped unless you're running on **Google Colab** as its logging root handler only shows warnings and errors by default.  If you'd like to see INFO statements you can run the following code.  This is particularly helpful when running some of the download examples so you can see the progress as downloads complete.

# %%
import logging

# Check current handlers
#print(logging.root.handlers)

# Remove all handlers associated with the root logger object.
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)
#print(logging.root.handlers)

# Set handler with level = info
logging.basicConfig(format='%(asctime)s:%(levelname)s:%(message)s',
                    level=logging.INFO)

print("Logging set to INFO")
# Out:
# Logging set to INFO

# %% [markdown]
# <a id = "summary"></a>
# # Summary
#
# Access to large, high-quality datasets is essential for researchers to understand disease and precision medicine pathways, especially in cancer. However, HIPAA constraints make sharing medical images outside an individual institution complex process. [The Cancer Imaging Archive (TCIA)](https://www.cancerimagingarchive.net/) is a public service funded by the National Cancer Institute which addresses this challenge by providing hosting and de-identification services to take major burdens of data sharing off researchers.<br>
#
# The tcia_utils package contains functions to simplify common tasks one might perform when interacting with The Cancer Imaging Archive (TCIA) via Jupyter/Python. Learn more about TCIA and its open-access datasets at https://www.cancerimagingarchive.net/. Please be sure to comply with the TCIA Data Usage Policy. Learn more about the tcia_utils package information on the PyPI page at https://pypi.org/project/tcia-utils/.

# %% [markdown]
# ## Installation

# %%
# !pip install --upgrade -q tcia-utils
# !pip install --upgrade -q pandas
# !pip install --upgrade -q requests
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 78.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.

# %% [markdown]
# ## Usage
# To import functions related to the NBIA software, which holds TCIA's DICOM radiology data:

# %%
import requests
import pandas as pd
from tcia_utils import nbia
# Out:
# 2025-03-06 12:34:13,974:INFO:NumExpr defaulting to 2 threads.

# %% [markdown]
# # 1. Learn about Available Collections on the TCIA Website
#
# [Browsing Collections](https://www.cancerimagingarchive.net/collections) and viewing [Analysis Results](https://www.cancerimagingarchive.net/tcia-analysis-results/) of TCIA datasets are the easiest ways to become familiar with what is available. These pages will help you quickly identify datasets of interest, find valuable supporting data that are not available via our APIs (e.g. clinical spreadsheets and non-DICOM segmentation data), and answer the most common questions you might have about the datasets.
#
# # 2. REST API Overview
# TCIA uses software called NBIA to manage DICOM data. The NBIA REST APIs are provided for the search and download functions used in the TCIA radiology portal and allow access to both public and limited access collections.
# 1. The [NBIA Search REST APIs](https://wiki.cancerimagingarchive.net/x/fILTB) allow you to perform basic queries and download data from **public** collections. These APIs do not require a TCIA account.
# 2. The [NBIA Search with Authentication REST APIs](https://wiki.cancerimagingarchive.net/x/X4ATBg) allow you to perform basic queries and download data from **public and limited-access** collections. These APIs require a TCIA account to create authentication tokens.
# 3. The [NBIA Advanced REST APIs](https://wiki.cancerimagingarchive.net/x/YoATBg) also allow access to **public and limited-access** collections, but provide query endpoints mostly geared towards developers seeking to integrate searching and downloading TCIA data into web and desktop applications. This API requires a TCIA account to create authentication tokens.

# %% [markdown]
# # 3. Query Functions
#
# Detailed usage of some of these functions can be found at https://github.com/kirbyju/TCIA_Notebooks/blob/main/TCIA_REST_API_Queries.ipynb.

# %% [markdown]
# ## queryData
#
# **Params: (endpoint, api_url)**
#
# * Provides error handling for requests.get()
# * Formats output as JSON by default with options for "df" (dataframe) and "csv"
# * Because it is called by query functions that use requests.get(), ***<font color='red'>please do NOT use this function</font>***.

# %% [markdown]
# ## getCollections
#
# **Params: (api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets a list of collections from a specified api_url

# %%
# If the format is not specified, it returns a JSON object.
nbia.getCollections(format = "", api_url="nlst")
# Out:
# 2025-03-06 12:45:10,634:INFO:Success - Token saved to global nlst_api_call_headers variable and expires at 2025-03-06 14:45:10.634679
# 2025-03-06 12:45:10,636:INFO:Calling getCollectionValues with parameters {}
# [{'Collection': 'NLST'}]

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getCollections(format = "df")
# Out:
# 2025-03-06 12:34:37,181:INFO:Calling getCollectionValues with parameters {}
#                         Collection
# 0                          4D-Lung
# 1                       ACRIN-6698
# 2    ACRIN-Contralateral-Breast-MR
# 3                 ACRIN-FLT-Breast
# 4              ACRIN-NSCLC-FDG-PET
# ..                             ...
# 124                      UPENN-GBM
# 125                 VAREPOP-APOLLO
# 126                         VICTRE
# 127    Vestibular-Schwannoma-MC-RC
# 128      Vestibular-Schwannoma-SEG
#
# [129 rows x 1 columns]

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getCollections(format = "csv")

# %% [markdown]
# ## getBodyPart
#
# **Params: (collection = "", modality = "", api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets Body Part Examined metadata from a specified api_url
# * Allows filtering by collection and modality

# %%
# If the format is not specified, it returns a JSON object.
nbia.getBodyPart(collection = "nlst", modality = "", format = "", api_url = "nlst")
# Out:
# 2025-03-06 12:45:39,649:INFO:Calling getBodyPartValues with parameters {'Collection': 'nlst'}
# [{}, {'BodyPartExamined': 'CHEST'}]

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getBodyPart(collection = "CPTAC-SAR", modality = "CT", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getBodyPart(collection = "CPTAC-SAR", modality = "CT", format = "csv")

# %% [markdown]
# ## getModality
#
# **Params: (collection = "", bodyPart = "", api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets Modalities metadata from a specified api_url
# * Allows filtering by collection and bodyPart

# %%
# If the format is not specified, it returns a JSON object.
nbia.getModality(collection = "NLST", format = "", api_url = "nlst")
# Out:
# 2025-03-06 12:46:17,005:INFO:Calling getModalityValues with parameters {'Collection': 'NLST'}
# [{'Modality': 'CT'}]

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getModality(collection = "CPTAC-SAR", bodyPart = "EXTREMITY", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getModality(collection = "CPTAC-SAR", bodyPart = "EXTREMITY", format = "csv")

# %% [markdown]
# ## getPatient
#
# **Params: (collection = "", api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets Patient metadata from a specified api_url
# * Allows filtering by collection

# %%
# If the format is not specified, it returns a JSON object.
nbia.getPatient(collection = "NLST", format = "", api_url = "nlst")
# Out:
# 2025-03-06 13:26:08,391:INFO:Calling getPatient with parameters {'Collection': 'NLST'}
# [{'PatientId': '120547',
#   'PatientName': '120527^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132926',
#   'PatientName': '088690^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '103433',
#   'PatientName': '133827^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133251',
#   'PatientName': '127704^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '116785',
#   'PatientName': '127498^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '107544',
#   'PatientName': '126466^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '130891',
#   'PatientName': '128207^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101337',
#   'PatientName': '135863^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100098',
#   'PatientName': '160192^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104262',
#   'PatientName': '118612^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '118275',
#   'PatientName': '097246^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123487',
#   'PatientName': '091116^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '130229',
#   'PatientName': '036509^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '134546',
#   'PatientName': '123190^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '107793',
#   'PatientName': '147058^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '131567',
#   'PatientName': '073312^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114193',
#   'PatientName': '137885^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105046',
#   'PatientName': '166199^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '108009',
#   'PatientName': '021550^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '120211',
#   'PatientName': '096636^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105706',
#   'PatientName': '050856^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123911',
#   'PatientName': '059006^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '116669',
#   'PatientName': '097394^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104913',
#   'PatientName': '085514^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109730',
#   'PatientName': '113480^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126556',
#   'PatientName': '019653^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '102987',
#   'PatientName': '117051^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '129020',
#   'PatientName': '140277^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101171',
#   'PatientName': '062687^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101152',
#   'PatientName': '000059^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125986',
#   'PatientName': '128231^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105908',
#   'PatientName': '155507^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100721',
#   'PatientName': '152686^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100329',
#   'PatientName': '054171^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121209',
#   'PatientName': '076489^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '108341',
#   'PatientName': '139741^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '120360',
#   'PatientName': '096180^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124958',
#   'PatientName': '099945^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '113550',
#   'PatientName': '041855^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '116311',
#   'PatientName': '065862^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124090',
#   'PatientName': '071977^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132748',
#   'PatientName': '019620^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '112407',
#   'PatientName': '012021^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '106935',
#   'PatientName': '044016^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '117354',
#   'PatientName': '093088^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126615',
#   'PatientName': '013714^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '134231',
#   'PatientName': '171314^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132741',
#   'PatientName': '077917^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '122719',
#   'PatientName': '059220^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104810',
#   'PatientName': '044842^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100768',
#   'PatientName': '120428^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '116828',
#   'PatientName': '005264^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105106',
#   'PatientName': '164293^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '106233',
#   'PatientName': '163808^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '103620',
#   'PatientName': '050724^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126893',
#   'PatientName': '003293^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '120781',
#   'PatientName': '082578^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '115854',
#   'PatientName': '059337^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '110629',
#   'PatientName': '084657^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '129074',
#   'PatientName': '145151^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123743',
#   'PatientName': '152959^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101005',
#   'PatientName': '136945^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '122221',
#   'PatientName': '099333^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '134436',
#   'PatientName': '058321^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '127852',
#   'PatientName': '082370^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121962',
#   'PatientName': '077909^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123221',
#   'PatientName': '048736^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126150',
#   'PatientName': '068197^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '108121',
#   'PatientName': '008581^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '131798',
#   'PatientName': '068205^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114797',
#   'PatientName': '024810^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101868',
#   'PatientName': '056127^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132472',
#   'PatientName': '003384^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125173',
#   'PatientName': '142281^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114550',
#   'PatientName': '049718^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105269',
#   'PatientName': '037119^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '103178',
#   'PatientName': '031039^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104094',
#   'PatientName': '138230^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '102509',
#   'PatientName': '051805^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125198',
#   'PatientName': '014936^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121338',
#   'PatientName': '116780^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '107689',
#   'PatientName': '088047^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114610',
#   'PatientName': '043133^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104305',
#   'PatientName': '096198^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '119338',
#   'PatientName': '011536^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '113693',
#   'PatientName': '148742^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '107777',
#   'PatientName': '043026^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '111278',
#   'PatientName': '084368^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126361',
#   'PatientName': '040857^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126001',
#   'PatientName': '111567^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121773',
#   'PatientName': '033522^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125762',
#   'PatientName': '066332^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '102348',
#   'PatientName': '037994^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114180',
#   'PatientName': '010611^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104162',
#   'PatientName': '150540^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '115988',
#   'PatientName': '111393^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104242',
#   'PatientName': '154427^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109133',
#   'PatientName': '002691^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '131895',
#   'PatientName': '120857^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '131525',
#   'PatientName': '111740^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132514',
#   'PatientName': '163758^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '119567',
#   'PatientName': '167254^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '110471',
#   'PatientName': '162560^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '122885',
#   'PatientName': '102947^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '108374',
#   'PatientName': '116954^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '106182',
#   'PatientName': '061143^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '111711',
#   'PatientName': '153676^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100437',
#   'PatientName': '166280^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100551',
#   'PatientName': '164657^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123096',
#   'PatientName': '047977^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '107771',
#   'PatientName': '022020^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '127277',
#   'PatientName': '123372^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109584',
#   'PatientName': '129999^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '134455',
#   'PatientName': '055822^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '111692',
#   'PatientName': '070938^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109386',
#   'PatientName': '086447^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101204',
#   'PatientName': '106914^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105882',
#   'PatientName': '059774^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100130',
#   'PatientName': '118539^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123179',
#   'PatientName': '146860^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109340',
#   'PatientName': '045625^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '129599',
#   'PatientName': '118794^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105141',
#   'PatientName': '163436^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '117991',
#   'PatientName': '134981^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '111428',
#   'PatientName': '051110^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105713',
#   'PatientName': '127209^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '113456',
#   'PatientName': '148619^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125442',
#   'PatientName': '123158^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133424',
#   'PatientName': '132522^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133976',
#   'PatientName': '021378^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104454',
#   'PatientName': '055285^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '108880',
#   'PatientName': '096651^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '119919',
#   'PatientName': '136986^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114728',
#   'PatientName': '087304^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125068',
#   'PatientName': '076000^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104188',
#   'PatientName': '017616^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109360',
#   'PatientName': '152785^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '115778',
#   'PatientName': '135384^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100524',
#   'PatientName': '030908^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '134401',
#   'PatientName': '066472^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '134527',
#   'PatientName': '118265^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '107655',
#   'PatientName': '014647^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '113685',
#   'PatientName': '109116^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '106355',
#   'PatientName': '172619^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '129050',
#   'PatientName': '049130^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114176',
#   'PatientName': '018184^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '119543',
#   'PatientName': '116517^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109998',
#   'PatientName': '153197^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104680',
#   'PatientName': '049569^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125512',
#   'PatientName': '123356^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '107320',
#   'PatientName': '013334^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '103785',
#   'PatientName': '052613^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109757',
#   'PatientName': '165597^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121354',
#   'PatientName': '090118^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '122556',
#   'PatientName': '026864^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '112817',
#   'PatientName': '032706^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '117819',
#   'PatientName': '159053^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '122096',
#   'PatientName': '024679^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '103416',
#   'PatientName': '023713^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121193',
#   'PatientName': '085712^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '118267',
#   'PatientName': '144253^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '102488',
#   'PatientName': '040253^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109303',
#   'PatientName': '078378^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '102038',
#   'PatientName': '142703^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '110155',
#   'PatientName': '086843^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101208',
#   'PatientName': '160465^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '129659',
#   'PatientName': '145821^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '102896',
#   'PatientName': '154369^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126493',
#   'PatientName': '113936^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125381',
#   'PatientName': '130054^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '130428',
#   'PatientName': '108134^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104713',
#   'PatientName': '065532^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '127895',
#   'PatientName': '047266^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '102184',
#   'PatientName': '145722^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124466',
#   'PatientName': '154211^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '117947',
#   'PatientName': '134403^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '118509',
#   'PatientName': '003830^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '106626',
#   'PatientName': '022434^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104077',
#   'PatientName': '028589^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121035',
#   'PatientName': '038265^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133408',
#   'PatientName': '002642^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '119464',
#   'PatientName': '051557^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101354',
#   'PatientName': '129924^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '122265',
#   'PatientName': '085902^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132688',
#   'PatientName': '054965^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '102837',
#   'PatientName': '115113^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '103903',
#   'PatientName': '023762^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133468',
#   'PatientName': '125534^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132817',
#   'PatientName': '005041^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133428',
#   'PatientName': '002758^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '129478',
#   'PatientName': '099069^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123118',
#   'PatientName': '114066^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '128781',
#   'PatientName': '075572^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124232',
#   'PatientName': '002303^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '129529',
#   'PatientName': '041236^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124436',
#   'PatientName': '017897^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '115036',
#   'PatientName': '073114^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121590',
#   'PatientName': '058610^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '111213',
#   'PatientName': '124511^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '118033',
#   'PatientName': '041574^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '122547',
#   'PatientName': '124578^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123378',
#   'PatientName': '103085^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '131628',
#   'PatientName': '073676^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126317',
#   'PatientName': '010686^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105168',
#   'PatientName': '034611^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '108908',
#   'PatientName': '149062^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '103042',
#   'PatientName': '043638^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '122700',
#   'PatientName': '126417^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105676',
#   'PatientName': '048686^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '110886',
#   'PatientName': '162255^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '110494',
#   'PatientName': '134528^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114938',
#   'PatientName': '035113^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100051',
#   'PatientName': '059584^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '110090',
#   'PatientName': '125351^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '106267',
#   'PatientName': '114439^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '106065',
#   'PatientName': '070797^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '120677',
#   'PatientName': '137521^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '118024',
#   'PatientName': '101097^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '131236',
#   'PatientName': '063115^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '115844',
#   'PatientName': '122317^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109936',
#   'PatientName': '060640^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '110025',
#   'PatientName': '141010^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '129130',
#   'PatientName': '003210^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '128645',
#   'PatientName': '041434^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126661',
#   'PatientName': '103366^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '130811',
#   'PatientName': '101774^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '117513',
#   'PatientName': '022319^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '118879',
#   'PatientName': '147074^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126564',
#   'PatientName': '050765^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '112554',
#   'PatientName': '153825^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124064',
#   'PatientName': '108548^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '122463',
#   'PatientName': '011833^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104211',
#   'PatientName': '083675^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123399',
#   'PatientName': '046490^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '131645',
#   'PatientName': '038752^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133922',
#   'PatientName': '112631^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '116775',
#   'PatientName': '081877^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125666',
#   'PatientName': '007591^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '128421',
#   'PatientName': '101279^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '120284',
#   'PatientName': '085803^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '106683',
#   'PatientName': '029991^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '104827',
#   'PatientName': '069344^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105222',
#   'PatientName': '107060^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109765',
#   'PatientName': '019489^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '134575',
#   'PatientName': '160762^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101750',
#   'PatientName': '157131^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '134116',
#   'PatientName': '140228^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '112268',
#   'PatientName': '117556^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '130759',
#   'PatientName': '138842^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '108159',
#   'PatientName': '141341^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '110293',
#   'PatientName': '127415^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '129983',
#   'PatientName': '140780^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '118151',
#   'PatientName': '050278^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '115304',
#   'PatientName': '167072^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '120497',
#   'PatientName': '034710^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '118570',
#   'PatientName': '060913^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101212',
#   'PatientName': '125229^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124558',
#   'PatientName': '145938^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133624',
#   'PatientName': '119446^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132686',
#   'PatientName': '069880^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '113132',
#   'PatientName': '077131^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132172',
#   'PatientName': '110429^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '120915',
#   'PatientName': '143180^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101606',
#   'PatientName': '021006^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '127652',
#   'PatientName': '075242^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '128698',
#   'PatientName': '080077^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '106227',
#   'PatientName': '034983^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114741',
#   'PatientName': '037077^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121154',
#   'PatientName': '012419^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '115926',
#   'PatientName': '162164^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114478',
#   'PatientName': '172254^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '116623',
#   'PatientName': '023689^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123697',
#   'PatientName': '152272^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114156',
#   'PatientName': '168930^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '128392',
#   'PatientName': '160564^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100817',
#   'PatientName': '129668^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124837',
#   'PatientName': '118232^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '115343',
#   'PatientName': '152611^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '119486',
#   'PatientName': '059642^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123488',
#   'PatientName': '136382^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '116257',
#   'PatientName': '141432^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105262',
#   'PatientName': '060202^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
# ...
#  {'PatientId': '105528',
#   'PatientName': '043034^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '106276',
#   'PatientName': '067835^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132104',
#   'PatientName': '024349^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '113754',
#   'PatientName': '115949^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125526',
#   'PatientName': '155630^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125365',
#   'PatientName': '003533^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133012',
#   'PatientName': '084285^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '116118',
#   'PatientName': '164715^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '103816',
#   'PatientName': '106617^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '117189',
#   'PatientName': '153619^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133658',
#   'PatientName': '012492^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '103712',
#   'PatientName': '070839^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105214',
#   'PatientName': '000273^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '108945',
#   'PatientName': '008995^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121800',
#   'PatientName': '111104^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '134410',
#   'PatientName': '140533^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133803',
#   'PatientName': '104695^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124354',
#   'PatientName': '011783^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '111007',
#   'PatientName': '156497^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '127893',
#   'PatientName': '017756^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100619',
#   'PatientName': '030841^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121665',
#   'PatientName': '136531^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '120375',
#   'PatientName': '133702^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '111902',
#   'PatientName': '056325^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '128670',
#   'PatientName': '056424^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '102171',
#   'PatientName': '043380^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '129904',
#   'PatientName': '087635^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105015',
#   'PatientName': '169953^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '129064',
#   'PatientName': '022848^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '122483',
#   'PatientName': '050732^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '128552',
#   'PatientName': '118851^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '113659',
#   'PatientName': '133363^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100597',
#   'PatientName': '008490^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132989',
#   'PatientName': '094839^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '131788',
#   'PatientName': '094656^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '113854',
#   'PatientName': '164723^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '106102',
#   'PatientName': '109595^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '119157',
#   'PatientName': '016535^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '103283',
#   'PatientName': '008219^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '105422',
#   'PatientName': '061960^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125078',
#   'PatientName': '106484^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101704',
#   'PatientName': '059725^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125047',
#   'PatientName': '028464^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '129494',
#   'PatientName': '100214^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124104',
#   'PatientName': '107300^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109666',
#   'PatientName': '069385^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114112',
#   'PatientName': '132431^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126216',
#   'PatientName': '149179^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '111567',
#   'PatientName': '137877^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '109660',
#   'PatientName': '014290^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114038',
#   'PatientName': '055921^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133207',
#   'PatientName': '005348^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '103561',
#   'PatientName': '007377^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124972',
#   'PatientName': '092411^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '110303',
#   'PatientName': '045930^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132646',
#   'PatientName': '045575^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '116964',
#   'PatientName': '066027^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '112779',
#   'PatientName': '054791^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121057',
#   'PatientName': '158816^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '111427',
#   'PatientName': '059394^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '110651',
#   'PatientName': '035733^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126599',
#   'PatientName': '080382^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '108161',
#   'PatientName': '068866^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123990',
#   'PatientName': '073627^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '108895',
#   'PatientName': '150680^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '107448',
#   'PatientName': '100958^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '115243',
#   'PatientName': '074807^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '119497',
#   'PatientName': '117622^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132539',
#   'PatientName': '069245^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101593',
#   'PatientName': '128199^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114479',
#   'PatientName': '171603^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '128337',
#   'PatientName': '134841^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121264',
#   'PatientName': '156166^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124338',
#   'PatientName': '001859^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '120009',
#   'PatientName': '113209^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '116182',
#   'PatientName': '004416^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133555',
#   'PatientName': '096628^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133419',
#   'PatientName': '162453^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '132915',
#   'PatientName': '009910^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '124825',
#   'PatientName': '003731^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '131241',
#   'PatientName': '095869^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '133054',
#   'PatientName': '097832^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '114326',
#   'PatientName': '088062^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '117820',
#   'PatientName': '097857^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '125478',
#   'PatientName': '159657^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '101937',
#   'PatientName': '076406^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '121965',
#   'PatientName': '093914^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '100700',
#   'PatientName': '049528^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '126966',
#   'PatientName': '127746^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '117222',
#   'PatientName': '057935^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '122498',
#   'PatientName': '094771^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123082',
#   'PatientName': '075416^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '130655',
#   'PatientName': '035998^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  {'PatientId': '123914',
#   'PatientName': '095596^LSS',
#   'Collection': 'NLST',
#   'Phantom': 'NO',
#   'SpeciesCode': '337915000',
#   'SpeciesDescription': 'Homo sapiens'},
#  ...]

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getPatient(collection = "CPTAC-SAR", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getPatient(collection = "CPTAC-SAR", format = "csv")

# %% [markdown]
# ## getPatientByCollectionAndModality
#
# **Params: (collection, modality, api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets Patient IDs from a specified api_url
# * Returns a list of patient IDs

# %%
# If the format is not specified, it returns a JSON object.
nbia.getPatientByCollectionAndModality(collection = "CPTAC-SAR", modality = "CT", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getPatientByCollectionAndModality(collection = "CPTAC-SAR", modality = "CT", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getPatientByCollectionAndModality(collection = "CPTAC-SAR", modality = "CT", format = "csv")

# %% [markdown]
# ## getNewPatientsInCollection
#
# **Params: (collection, date, api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets "new" patient metadata from a specified api_url
# * The date format is YYYY/MM/DD

# %%
# If the format is not specified, it returns a JSON object.
nbia.getNewPatientsInCollection(collection = "CPTAC-SAR", date = "2000/08/20", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getNewPatientsInCollection(collection = "CPTAC-SAR", date = "2000/08/20", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getNewPatientsInCollection(collection = "CPTAC-SAR", date = "2000/08/20", format = "csv")

# %% [markdown]
# ## getStudy
#
# **Params: (collection, patientId = "", studyUid = "", api_url = "", format = "")**
# * *Optional: patientId, studyUid, api_url, format*
# * Gets Study (visit/timepoint) metadata from a specified api_url

# %%
# If the format is not specified, it returns a JSON object.
nbia.getStudy(collection = "CPTAC-SAR", patientId = "", studyUid = "", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getStudy(collection = "NLST", patientId = "", studyUid = "", format = "df", api_url = "nlst")
# Out:
# 2025-03-06 13:26:42,263:INFO:Calling getPatientStudy with parameters {'Collection': 'NLST'}
#                                         StudyInstanceUID  \
# 0      1.2.840.113654.2.55.21337110091883201191948633...
# 1      1.2.840.113654.2.55.90802099130330794954208063...
# 2      1.2.840.113654.2.55.75169798136366389188206491...
# 3      1.2.840.113654.2.55.61575840666785011417955514...
# 4      1.2.840.113654.2.55.15863127437745398843582988...
# ...                                                  ...
# 73111  1.3.6.1.4.1.14519.5.2.1.7009.9004.582591325828...
# 73112  1.3.6.1.4.1.14519.5.2.1.7009.9004.334249300779...
# 73113  1.3.6.1.4.1.14519.5.2.1.7009.9004.261308004152...
# 73114  1.3.6.1.4.1.14519.5.2.1.7009.9004.104162954107...
# 73115  1.3.6.1.4.1.14519.5.2.1.7009.9004.155817740944...
#
#                    StudyDate StudyDescription PatientID  PatientName  \
# 0      2000-01-02 00:00:00.0         NLST-LSS    120547   120527^LSS
# 1      2000-01-02 00:00:00.0         NLST-LSS    132926   088690^LSS
# 2      2000-01-02 00:00:00.0         NLST-LSS    103433   133827^LSS
# 3      2000-01-02 00:00:00.0         NLST-LSS    133251   127704^LSS
# 4      2000-01-02 00:00:00.0         NLST-LSS    116785   127498^LSS
# ...                      ...              ...       ...          ...
# 73111  2001-01-02 00:00:00.0       NLST-ACRIN    211685  15861^ACRIN
# 73112  1999-01-02 00:00:00.0       NLST-ACRIN    208005   2731^ACRIN
# 73113  1999-01-02 00:00:00.0       NLST-ACRIN    218123   3070^ACRIN
# 73114  2000-01-02 00:00:00.0       NLST-ACRIN    215959  14788^ACRIN
# 73115  2000-01-02 00:00:00.0       NLST-ACRIN    207899   3050^ACRIN
#
#       Collection  SeriesCount
# 0           NLST            3
# 1           NLST            3
# 2           NLST            3
# 3           NLST            3
# 4           NLST            3
# ...          ...          ...
# 73111       NLST            1
# 73112       NLST            1
# 73113       NLST            1
# 73114       NLST            2
# 73115       NLST            1
#
# [73116 rows x 7 columns]

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getStudy(collection = "NLST", patientId = "", studyUid = "", format = "csv", api_url = "nlst")
# Out:
# 2025-03-06 13:29:17,844:INFO:Calling getPatientStudy with parameters {'Collection': 'NLST'}
# 2025-03-06 13:29:29,088:INFO:CSV saved to: getPatientStudy_2025-03-06_13-29.csv
#                                         StudyInstanceUID  \
# 0      1.2.840.113654.2.55.21337110091883201191948633...
# 1      1.2.840.113654.2.55.90802099130330794954208063...
# 2      1.2.840.113654.2.55.75169798136366389188206491...
# 3      1.2.840.113654.2.55.61575840666785011417955514...
# 4      1.2.840.113654.2.55.15863127437745398843582988...
# ...                                                  ...
# 73111  1.3.6.1.4.1.14519.5.2.1.7009.9004.582591325828...
# 73112  1.3.6.1.4.1.14519.5.2.1.7009.9004.334249300779...
# 73113  1.3.6.1.4.1.14519.5.2.1.7009.9004.261308004152...
# 73114  1.3.6.1.4.1.14519.5.2.1.7009.9004.104162954107...
# 73115  1.3.6.1.4.1.14519.5.2.1.7009.9004.155817740944...
#
#                    StudyDate StudyDescription PatientID  PatientName  \
# 0      2000-01-02 00:00:00.0         NLST-LSS    120547   120527^LSS
# 1      2000-01-02 00:00:00.0         NLST-LSS    132926   088690^LSS
# 2      2000-01-02 00:00:00.0         NLST-LSS    103433   133827^LSS
# 3      2000-01-02 00:00:00.0         NLST-LSS    133251   127704^LSS
# 4      2000-01-02 00:00:00.0         NLST-LSS    116785   127498^LSS
# ...                      ...              ...       ...          ...
# 73111  2001-01-02 00:00:00.0       NLST-ACRIN    211685  15861^ACRIN
# 73112  1999-01-02 00:00:00.0       NLST-ACRIN    208005   2731^ACRIN
# 73113  1999-01-02 00:00:00.0       NLST-ACRIN    218123   3070^ACRIN
# 73114  2000-01-02 00:00:00.0       NLST-ACRIN    215959  14788^ACRIN
# 73115  2000-01-02 00:00:00.0       NLST-ACRIN    207899   3050^ACRIN
#
#       Collection  SeriesCount
# 0           NLST            3
# 1           NLST            3
# 2           NLST            3
# 3           NLST            3
# 4           NLST            3
# ...          ...          ...
# 73111       NLST            1
# 73112       NLST            1
# 73113       NLST            1
# 73114       NLST            2
# 73115       NLST            1
#
# [73116 rows x 7 columns]

# %% [markdown]
# ## getNewStudiesInPatient
# **Params: (collection, patientId, date, api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets "new" patient metadata from a specified api_url
# * The date format is YYYY/MM/DD

# %%
# If the format is not specified, it returns a JSON object.
nbia.getNewStudiesInPatient(collection = "CPTAC-SAR", patientId = "C3N-00843", date = "2010/09/06", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getNewStudiesInPatient(collection = "CPTAC-SAR", patientId = "C3N-00843", date = "2010/09/06", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getNewStudiesInPatient(collection = "CPTAC-SAR", patientId = "C3N-00843", date = "2010/09/06", format = "csv")

# %% [markdown]
# ## getSeries
#
# **Params: (collection = "", patientId = "", studyUid = "", seriesUid = "", modality = "", bodyPart = "",<br>
# manufacturer = "", manufacturerModel = "", api_url = "", format = "")**
#
# * *All parameters are optional.*
# * Gets Series (scan) metadata from a specified api_url
# * Allows filtering by collection, patient ID, study UID, series UID, modality, body part, manufacturer & model
# * ***Note: Since the output of this function can be very long, it is advisable to save the output to a variable and only display a portion of it at a time when the output format is JSON.***

# %%
# If the format is not specified, it returns a JSON object.
data = nbia.getSeries(collection = "CPTAC-SAR", patientId = "", studyUid = "", seriesUid = "",
                    modality = "", bodyPart = "", manufacturer = "", manufacturerModel = "", format = "")

sample = data[:3]
print(sample)

# %%
# If the format is set to "df", it returns a pandas dataframe object.
df_series = nbia.getSeries(collection = "NLST", patientId = "", studyUid = "", seriesUid = "",
                    modality = "", bodyPart = "", manufacturer = "", manufacturerModel = "", format = "df", api_url = "nlst")
df_series.shape
# Out:
# 2025-03-06 13:32:36,220:INFO:Calling getSeries with parameters {'Collection': 'NLST'}
# (203099, 17)

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getSeries(collection = "NLST", patientId = "", studyUid = "", seriesUid = "",
                    modality = "", bodyPart = "", manufacturer = "", manufacturerModel = "", format = "csv", api_url = "nlst")
# Out:
# 2025-03-06 13:30:18,577:INFO:Calling getSeries with parameters {'Collection': 'NLST'}
# 2025-03-06 13:31:29,530:INFO:CSV saved to: getSeries_2025-03-06_13-31.csv
#                                         SeriesInstanceUID  \
# 0       1.2.840.113654.2.55.23441925956228557802682238...
# 1       1.2.840.113654.2.55.73018454204713920560741393...
# 2       1.2.840.113654.2.55.30398261728946816912167636...
# 3       1.2.840.113654.2.55.86332662914396060696692073...
# 4       1.2.840.113654.2.55.52981101727088544427378915...
# ...                                                   ...
# 203094  1.3.6.1.4.1.14519.5.2.1.7009.9004.213580592718...
# 203095  1.3.6.1.4.1.14519.5.2.1.7009.9004.134476479426...
# 203096  1.3.6.1.4.1.14519.5.2.1.7009.9004.286270319730...
# 203097  1.3.6.1.4.1.14519.5.2.1.7009.9004.683091683582...
# 203098  1.3.6.1.4.1.14519.5.2.1.7009.9004.234309195522...
#
#                                          StudyInstanceUID Modality  \
# 0       1.2.840.113654.2.55.30786626814769709557761229...       CT
# 1       1.2.840.113654.2.55.30786626814769709557761229...       CT
# 2       1.2.840.113654.2.55.30786626814769709557761229...       CT
# 3       1.2.840.113654.2.55.26752767808118968579250026...       CT
# 4       1.2.840.113654.2.55.26752767808118968579250026...       CT
# ...                                                   ...      ...
# 203094  1.3.6.1.4.1.14519.5.2.1.7009.9004.174278491747...       CT
# 203095  1.3.6.1.4.1.14519.5.2.1.7009.9004.274135601985...       CT
# 203096  1.3.6.1.4.1.14519.5.2.1.7009.9004.211266745836...       CT
# 203097  1.3.6.1.4.1.14519.5.2.1.7009.9004.211266745836...       CT
# 203098  1.3.6.1.4.1.14519.5.2.1.7009.9004.318568746847...       CT
#
#                                   SeriesDescription  SeriesNumber Collection  \
# 0       1,OPL,PH,MX8000,UNK,500,na,90,null,1.0,null          7122       NLST
# 1       1,OPA,PH,MX8000,C,342,3.2,120,80.0,0.1,1.75          7123       NLST
# 2       1,OPA,PH,MX8000,D,342,3.2,120,80.0,0.1,1.75          7124       NLST
# 3       1,OPL,PH,MX8000,UNK,500,na,90,null,1.0,null          6957       NLST
# 4       1,OPA,PH,MX8000,C,315,3.2,120,39.0,0.0,1.75          6958       NLST
# ...                                             ...           ...        ...
# 203094   2,DSR,GE,LSULT,BONE,330,na,120,55,36.7,1.5           690       NLST
# 203095   2,DSR,GE,LSULT,BONE,360,na,120,80,53.3,1.5           906       NLST
# 203096          2,DS,PH,MX8000,unkn,0,0,na,na,na,na          5022       NLST
# 203097          2,DS,PH,MX8000,unkn,0,0,na,na,na,na          5023       NLST
# 203098         2,DSA,PH,MX8000,unkn,0,0,na,na,na,na        861527       NLST
#
#        PatientID        Manufacturer ManufacturerModelName SoftwareVersions  \
# 0         113685             Philips                Mx8000              2.2
# 1         113685             Philips                Mx8000              2.2
# 2         113685             Philips                Mx8000              2.2
# 3         106355             Philips                Mx8000              2.2
# 4         106355             Philips                Mx8000              2.2
# ...          ...                 ...                   ...              ...
# 203094    205898  GE MEDICAL SYSTEMS      LightSpeed Ultra              NaN
# 203095    202343  GE MEDICAL SYSTEMS      LightSpeed Ultra              NaN
# 203096    200479             Philips                Mx8000              NaN
# 203097    200479             Philips                Mx8000              NaN
# 203098    207903             Philips                Mx8000              NaN
#
#         ImageCount              TimeStamp  \
# 0                3  2012-06-19 11:49:27.0
# 1              160  2012-06-19 11:50:08.0
# 2              160  2012-06-19 11:50:55.0
# 3                3  2012-06-19 11:51:00.0
# 4              161  2012-06-19 11:51:45.0
# ...            ...                    ...
# 203094          29  2013-02-23 08:21:54.0
# 203095          30  2013-02-23 08:24:03.0
# 203096         175  2013-02-23 00:31:10.0
# 203097         175  2013-02-23 00:32:11.0
# 203098         162  2013-02-23 05:11:02.0
#
#                                               LicenseName  \
# 0       Creative Commons Attribution 4.0 International...
# 1       Creative Commons Attribution 4.0 International...
# 2       Creative Commons Attribution 4.0 International...
# 3       Creative Commons Attribution 4.0 International...
# 4       Creative Commons Attribution 4.0 International...
# ...                                                   ...
# 203094  Creative Commons Attribution 4.0 International...
# 203095  Creative Commons Attribution 4.0 International...
# 203096  Creative Commons Attribution 4.0 International...
# 203097  Creative Commons Attribution 4.0 International...
# 203098  Creative Commons Attribution 4.0 International...
#
#                                           LicenseURI  \
# 0       https://creativecommons.org/licenses/by/4.0/
# 1       https://creativecommons.org/licenses/by/4.0/
# 2       https://creativecommons.org/licenses/by/4.0/
# 3       https://creativecommons.org/licenses/by/4.0/
# 4       https://creativecommons.org/licenses/by/4.0/
# ...                                              ...
# 203094  https://creativecommons.org/licenses/by/4.0/
# 203095  https://creativecommons.org/licenses/by/4.0/
# 203096  https://creativecommons.org/licenses/by/4.0/
# 203097  https://creativecommons.org/licenses/by/4.0/
# 203098  https://creativecommons.org/licenses/by/4.0/
#
#                                  CollectionURI   FileSize BodyPartExamined
# 0       https://doi.org/10.7937/TCIA.HMQ8-J677    1735712              NaN
# 1       https://doi.org/10.7937/TCIA.HMQ8-J677   84219688              NaN
# 2       https://doi.org/10.7937/TCIA.HMQ8-J677   84220044              NaN
# 3       https://doi.org/10.7937/TCIA.HMQ8-J677    1735694              NaN
# 4       https://doi.org/10.7937/TCIA.HMQ8-J677   84746162              NaN
# ...                                        ...        ...              ...
# 203094  https://doi.org/10.7937/TCIA.HMQ8-J677   15277318            CHEST
# 203095  https://doi.org/10.7937/TCIA.HMQ8-J677   15804230            CHEST
# 203096  https://doi.org/10.7937/TCIA.HMQ8-J677  110350602            CHEST
# 203097  https://doi.org/10.7937/TCIA.HMQ8-J677  110350602            CHEST
# 203098  https://doi.org/10.7937/TCIA.HMQ8-J677  102167046            CHEST
#
# [203099 rows x 17 columns]

# %%
df_series['PatientID'].nunique()
# Out:
# 26254

# %% [markdown]
# ## getUpdatedSeries
# **Params: (date, api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets "new" series metadata from a specified api_url
# * The date format is YYYY/MM/DD
# * ***NOTE: Unlike other API endpoints, this function expects MM/DD/YYYY, we'll convert from YYYY/MM/DD so tcia-utils is consistent***

# %%
# If the format is not specified, it returns a JSON object.
nbia.getUpdatedSeries(date = "2010/09/06", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getUpdatedSeries(date = "2010/09/06", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getUpdatedSeries(date = "2010/09/06", format = "csv")

# %% [markdown]
# ## getSeriesMetadata
# **Params: (seriesUid, api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets Series (scan) metadata from a specified api_url
# * Output includes DOI and license details that are not in the getSeries() function

# %%
# If the format is not specified, it returns a JSON object.
nbia.getSeriesMetadata(seriesUid = "1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getSeriesMetadata(seriesUid = "1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getSeriesMetadata(seriesUid = "1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", format = "csv")

# %% [markdown]
# ## getSeriesSize
# **Params: (seriesUid, api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets the file count and disk size of a series/scan

# %%
# If the format is not specified, it returns a JSON object.
nbia.getSeriesSize(seriesUid = "1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getSeriesSize(seriesUid = "1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getSeriesSize(seriesUid = "1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", format = "csv")

# %% [markdown]
# ## getSopInstanceUids
# **Params: (seriesUid, api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets SOP Instance UIDs from a specific series/scan

# %%
# If the format is not specified, it returns a JSON object.
nbia.getSopInstanceUids(seriesUid = "1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getSopInstanceUids(seriesUid = "1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getSopInstanceUids(seriesUid = "1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", format = "csv")

# %% [markdown]
# ## getManufacturer
# **Params: (collection = "", modality = "", bodyPart = "", api_url = "", format = "")**
#
# * *All parameters are optional.*
# * Gets manufacturer metadata from a specified api_url
# * Allows filtering by collection, body part & modality

# %%
# If the format is not specified, it returns a JSON object.
nbia.getManufacturer(collection = "", modality = "", bodyPart = "", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getManufacturer(collection = "", modality = "", bodyPart = "", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getManufacturer(collection = "", modality = "", bodyPart = "", format = "csv")

# %% [markdown]
# ## getSharedCart
#
# **Params: (name, api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets "Shared Cart" (scan) metadata from a specified api_url<br>
# * First use https://nbia.cancerimagingarchive.net/nbia-search/ to create a cart, then add data to your basket, then click "Share" > "Share my cart".
# * The "name" parameter is part of the URL that generates. E.g https://nbia.cancerimagingarchive.net/nbia-search/?saved-cart=nbia-49121659384603347 has a cart "name" of "nbia-49121659384603347".

# %%
# If the format is not specified, it returns a JSON object.
nbia.getSharedCart(name = "nbia-49121659384603347", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getSharedCart(name = "nbia-49121659384603347", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getSharedCart(name = "nbia-49121659384603347", format = "csv")

# %% [markdown]
# ## getCollectionDescriptions
#
# **Params: (api_url = "", format = "")**
#
# * *All parameters are optional.*
# * Gets HTML-formatted descriptions of collections and their DOIs

# %%
# If the format is not specified, it returns a JSON object.
nbia.getCollectionDescriptions(format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getCollectionDescriptions(format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getCollectionDescriptions(format = "csv")

# %% [markdown]
# ## getCollectionPatientCounts
# **Params: (api_url = "", format = "")**
#
# * *All parameters are optional.*
# * Gets counts of Patient by collection from Advanced API

# %%
# If the format is not specified, it returns a JSON object.
nbia.getCollectionPatientCounts(format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getCollectionPatientCounts(format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getCollectionPatientCounts(format = "csv")

# %% [markdown]
# ## getModalityCounts
#
# **Params: (collection = "", bodyPart = "", api_url = "", format = "")**
#
# * *All parameters are optional.*
# * Gets counts of Modality metadata from Advanced API
# * Allows filtering by collection and bodyPart

# %%
# If the format is not specified, it returns a JSON object.
nbia.getModalityCounts(collection = "CPTAC-SAR", bodyPart = "", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getModalityCounts(collection = "CPTAC-SAR", bodyPart = "EXTREMITY", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getModalityCounts(collection = "CPTAC-SAR", bodyPart = "EXTREMITY", format = "csv")

# %% [markdown]
# ## getBodyPartCounts
#
# **Params: (collection = "", modality = "", api_url = "", format = "")**
#
# * *All parameters are optional.*
# * Gets counts of Body Part metadata from Advanced API
# * Allows filtering by collection and modality

# %%
# If the format is not specified, it returns a JSON object.
nbia.getBodyPartCounts(collection = "CPTAC-SAR", modality = "CT", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getBodyPartCounts(collection = "CPTAC-SAR", modality = "CT", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getBodyPartCounts(collection = "CPTAC-SAR", modality = "CT", format = "csv")

# %% [markdown]
# ## getManufacturerCounts
#
# **Params: (collection = "", modality = "", bodyPart = "", api_url = "", format = "")**
#
# * *All parameters are optional.*
# * Gets counts of Manufacturer metadata from Advanced API
# * Allows filtering by collection, body part and modality

# %%
# If the format is not specified, it returns a JSON object.
nbia.getManufacturerCounts(collection = "CPTAC-SAR",  modality = "CT", bodyPart = "", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getManufacturerCounts(collection = "CPTAC-SAR",  modality = "CT", bodyPart = "", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getManufacturerCounts(collection = "CPTAC-SAR",  modality = "CT", bodyPart = "", format = "csv")

# %% [markdown]
# ## getSeriesList
#
# **Params: (list, api_url = "", csv_filename = "")**
#
# * *Optional: api_url, csv_filename*
# * Get series metadata from Advanced API
# * Allows submission of a list of UIDs
# * Returns result as dataframe and CSV

# %%
series_list = ["1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", "1.3.6.1.4.1.14519.5.2.1.6834.5010.215193814203822462481389051414"]
nbia.getSeriesList(list = series_list)

# %% [markdown]
# ## getDicomTags
#
# **Params: (seriesUid, api_url = "", format = "")**
#
# * *Optional: api_url, format*
# * Gets DICOM tag metadata for a given series UID (scan)

# %%
# If the format is not specified, it returns a JSON object.
nbia.getDicomTags(seriesUid = "1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getDicomTags(seriesUid = "1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getDicomTags(seriesUid = "1.3.6.1.4.1.14519.5.2.1.3320.3273.106936860187940539374736870621", format = "csv")

# %% [markdown]
# ## getSegRefSeries
# **Params: (uid)**
#
# * Looks up the series UID where a given SEG/RTSTRUCT series UID (scan) is derived from
# * Returns a dataframe

# %%
nbia.getSegRefSeries("1.3.6.1.4.1.14519.5.2.1.267656005479923851264209489600557009114")

# %% [markdown]
# ## getDoiMetadata
#
# **Params: (doi, output, api_url = "", format = "")**
#
# * *Optional: output, api_url, format*
# * Gets a list of Collections if output = "", or Series if output = "series", associated with a DOI.
# * The result includes whether the data are 3rd party analyses or not.

# %%
# If the format is not specified, it returns a JSON object.
nbia.getDoiMetadata(doi = "https://doi.org/10.7937/K9/TCIA.2018.PAT12TBS", output = "", format = "")

# %%
# If the format is not specified, it returns a JSON object.
nbia.getDoiMetadata(doi = "https://doi.org/10.7937/K9/TCIA.2018.PAT12TBS", output = "series", format = "")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getDoiMetadata(doi = "https://doi.org/10.7937/K9/TCIA.2018.PAT12TBS", output = "", format = "df")

# %%
# If the format is set to "df", it returns a pandas dataframe object.
nbia.getDoiMetadata(doi = "https://doi.org/10.7937/K9/TCIA.2018.PAT12TBS", output = "series", format = "df")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getDoiMetadata(doi = "https://doi.org/10.7937/K9/TCIA.2018.PAT12TBS", output = "", format = "csv")

# %%
# If the format is set to "csv", it saves a csv file to the workspace.
nbia.getDoiMetadata(doi = "https://doi.org/10.7937/K9/TCIA.2018.PAT12TBS", output = "series", format = "csv")

# %% [markdown]
# ## getSimpleSearchWithModalityAndBodyPartPaged
#
# **Params: (collections = [], species = [], modalities = [], bodyParts = [], manufacturers  = [], <br>
# fromDate = "", toDate = "", patients = [], minStudies: int = 0, modalityAnded = False, <br>
# start = 0, size = 10, sortDirection = 'ascending', sortField = 'subject', api_url = "", format = "")**
#
# * *All parameters are optional.*
# * Takes the same parameters as the SimpleSearch GUI
# * Use more parameters to narrow the number of subjects received.
# * **Note: This function only supports output of JSON format, please leavel the format parameter as it.**

# %%
nbia.getSimpleSearchWithModalityAndBodyPartPaged(collections = ["CPTAC-LUAD"], modalities = ["CT"], format = "")

# %% [markdown]
# # 4. Download Functions
#
# Detailed usage of some of these functions can be found at https://github.com/kirbyju/TCIA_Notebooks/blob/main/TCIA_REST_API_Downloads.ipynb.

# %% [markdown]
# ## downloadSeries
#
# **Params: (series_data, number = 0, path = "", hash = "", api_url = "",<br>
# input_type = "", format = "", csv_filename = "")**
#
# * Ingests a set of seriesUids and downloads them
# * By default, series_data expects JSON containing "SeriesInstanceUID" elements.
# * Set number = n to download the first n series if you don't want the full dataset.
# * Set hash = "y" if you'd like to retrieve MD5 hash values for each image.
# * Saves to tciaDownload folder in current directory if no path is specified
# * Set input_type = "list" to pass a list of Series UIDs instead of JSON.
# * Set input_type = "manifest" to pass the path of a *.TCIA manifest file as series_data.
# * Format can be set to "df" or "csv" to return series metadata.
# * Setting a csv_filename will create the csv even if format isn't specified.
# * The metadata includes info about series that have previously been downloaded.

# %%
import pickle

# Open the pickle file in binary read mode
with open("series_uids.pkl", "rb") as file:
    series_uids = pickle.load(file)

# Check the length of the loaded data
print(len(series_uids))
# Out:
# 132274

# %%
series_uids[0]
# Out:
# '1.2.840.113654.2.55.234419259562285578026822387336038908341'

# %%
nbia.downloadSeries(series_data = series_uids, number = 0, path = "/content/path", hash = "", api_url = "nlst", input_type= "list", format = "", csv_filename = "")
# Out:
# 2025-03-06 13:58:08,740:INFO:Downloading 132274 out of 132274 Series Instance UIDs (scans).
# 2025-03-06 13:58:08,753:INFO:Directory '/content/path' already exists.
# 2025-03-06 13:58:08,758:INFO:Downloading... https://nlst.cancerimagingarchive.net/nbia-api/services/v2/getImage?NewFileNames=Yes&SeriesInstanceUID=1.2.840.113654.2.55.234419259562285578026822387336038908341
# 2025-03-06 13:58:10,631:INFO:Downloading... https://nlst.cancerimagingarchive.net/nbia-api/services/v2/getImage?NewFileNames=Yes&SeriesInstanceUID=1.2.840.113654.2.55.73018454204713920560741393122781666991
# 2025-03-06 13:58:22,012:INFO:Downloading... https://nlst.cancerimagingarchive.net/nbia-api/services/v2/getImage?NewFileNames=Yes&SeriesInstanceUID=1.2.840.113654.2.55.303982617289468169121676367649394260610
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-82994537d06b> in <cell line: 0>()
# ----> 1 nbia.downloadSeries(series_data = series_uids, number = 0, path = "/content/path", hash = "", api_url = "nlst", input_type= "list", format = "", csv_filename = "")
#
# /usr/local/lib/python3.11/dist-packages/tcia_utils/nbia.py in downloadSeries(series_data, number, path, hash, api_url, input_type, format, csv_filename, as_zip)
#     819                 # Download data
#     820                 _log.info(f"Downloading... {data_url}")
# --> 821                 data = requests.get(data_url, headers=headers)
#     822                 if data.status_code == 200:
#     823                     # If `as_zip` is True, save the response as a zip file and don't extract it
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#    1061         """
#    1062         if self.chunked and self.supports_chunked_reads():
# -> 1063             yield from self.read_chunked(amt, decode_content=decode_content)
#    1064         else:
#    1065             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#    1217
#    1218             while True:
# -> 1219                 self._update_chunk_length()
#    1220                 if self.chunk_left == 0:
#    1221                     break
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in _update_chunk_length(self)
#    1136         if self.chunk_left is not None:
#    1137             return None
# -> 1138         line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1139         line = line.split(b";", 1)[0]
#    1140         try:
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# /usr/lib/python3.11/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1312                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313                   self.__class__)
# -> 1314             return self.read(nbytes, buffer)
#    1315         else:
#    1316             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1164         try:
#    1165             if buffer is not None:
# -> 1166                 return self._sslobj.read(len, buffer)
#    1167             else:
#    1168                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
nbia.viewSeries(series_uids[0])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-29-adc985d65626> in <cell line: 0>()
# ----> 1 nbia.viewSeries(series_uids[0])
#
# /usr/local/lib/python3.11/dist-packages/tcia_utils/nbia.py in viewSeries(*args, **kwargs)
#    2257         viewSeries(path = "")
#    2258     """
# -> 2259     raise NotImplementedError("viewSeries() has been migrated to the `simpleDicomViewer` PyPI package.")
#    2260
#    2261
#
# NotImplementedError: viewSeries() has been migrated to the `simpleDicomViewer` PyPI package.

# %% [markdown]
# ## downloadImage
# **Params: (downloadImage(seriesUID, sopUID, path = "", api_url = ""))**
#
# * Ingests a seriesUids and SopInstanceUid and downloads the image

# %% [markdown]
# # 5. Image Visualization Functions
#
# Detailed usage of these functions can be found at https://github.com/kirbyju/TCIA_Notebooks/blob/main/TCIA_REST_API_Queries.ipynb.

# %% [markdown]
# ## viewSeries
#
# **Params: (seriesUid = "", path = "")**
#
# * Visualizes a Series (scan) you've downloaded in the notebook
# * Requires EITHER a seriesUid or path parameter
# * Leave seriesUid empty if you want to provide a custom path.
# * The function assumes "tciaDownload/\<seriesUid\>/" as path if seriesUid is provided since this is where downloadSeries() saves data.

# %% [markdown]
# ## viewSeriesAnnotation
#
# **Params: (seriesUid = "", seriesPath = "", annotationUid = "", annotationPath = "")**
#
# * Visualizes a Series (scan) you've downloaded in the notebook
# * Adds an overlay from the annotative series (SEG or RTSTRUCT)
# * Directs to the correct visualization function depending on the modality of the annotative series
# * Requires EITHER a seriesUid or path parameter for the reference series
# * Requires EITHER a annotationUid or path parameter for the segmentation series
# * Opens a file browser for users to choose folder/file if the required parameters are not specified
# * Leave seriesUid and/or annotationUid empty if you want to provide a custom path
# * The function assumes "tciaDownload/\<UID\>/" as path if seriesUid and/or annotationUid is provided since this is where downloadSeries() saves data
# * ***<font color='red'>Note that non-axial images might not be correctly displayed.***

# %% [markdown]
# ### Using NSCLC-Radiomic dataset to demostrate the visualization of segmentation data
# In the following demostrations, I will show how to visualize SEG and RTSTRUCT data as an overlay on top of the reference series.
# * Ref Series UID: 1.3.6.1.4.1.32722.99.99.298991776521342375010861296712563382046
# * SEG Series UID: 1.2.276.0.7230010.3.1.3.2323910823.20524.1597260509.554
# * RT  Series UID: 1.3.6.1.4.1.32722.99.99.298991776521342375010861296712563382046
#
# The workflow is the same as the base viewSeries() function, in which the user inputs either the series UID or the path to the DICOM folder/file.
#
# In the visualization, users are able to toggle on and off the overlay as they desire, or individual segments if there are more than one presented in the data.

# %%
# This visualizes the SEG DICOM file
nbia.viewSeriesAnnotation("", "/Users/adam/Documents/SlicerDICOMDatabase/TCIALocal/1.3.6.1.4.1.32722.99.99.298991776521342375010861296712563382046/images", "", "/Users/adam/Documents/SlicerDICOMDatabase/TCIALocal/1.2.276.0.7230010.3.1.3.2323910823.20524.1597260509.554/images/1-1.dcm")

# %%
# This visualizes the RTSTRUCT DICOM file
nbia.viewSeriesAnnotation("", "/Users/adam/Documents/SlicerDICOMDatabase/TCIALocal/1.3.6.1.4.1.32722.99.99.298991776521342375010861296712563382046/images", "", "/Users/adam/Documents/SlicerDICOMDatabase/TCIALocal/1.3.6.1.4.1.32722.99.99.227938121586608072508444156170535578236/images/1-1.dcm")

# %%
# The function will prompt the user to choose the folder and/or file
nbia.viewSeriesAnnotation()

# %% [markdown]
# ## viewSeriesSEG
#
# **Params: (seriesPath = "", SEGPath = "")**
#
# * Visualizes a Series (scan) you've downloaded in the notebook
# * Adds an overlay from the SEG series
# * Requires a path parameter for the reference series
# * Requires the file path for the annotative series
# * ***<font color='red'>Not recommended to be used as a standalone function***

# %%
nbia.viewSeriesSEG("/Users/adam/Documents/SlicerDICOMDatabase/TCIALocal/1.3.6.1.4.1.32722.99.99.298991776521342375010861296712563382046/images", "/Users/adam/Documents/SlicerDICOMDatabase/TCIALocal/1.2.276.0.7230010.3.1.3.2323910823.20524.1597260509.554/images/1-1.dcm")

# %% [markdown]
# ## viewSeriesRT
#
# **Params: (seriesPath = "", RTath = "")**
#
# * Visualizes a Series (scan) you've downloaded in the notebook
# * Adds an overlay from the RTSTRUCT series
# * Requires a path parameter for the reference series
# * Requires the file path for the annotative series
# * ***<font color='red'>Not recommended to be used as a standalone function***

# %%
nbia.viewSeriesRT("/Users/adam/Documents/SlicerDICOMDatabase/TCIALocal/1.3.6.1.4.1.32722.99.99.298991776521342375010861296712563382046/images", "/Users/adam/Documents/SlicerDICOMDatabase/TCIALocal/1.3.6.1.4.1.32722.99.99.227938121586608072508444156170535578236/images/1-1.dcm")

# %% [markdown]
# ## makeVizLinks
#
# **Params: (series_data, csv_filename="")**
#
# * Ingests JSON output of getSeries() or getSharedCart()
# * Creates URLs to visualize them in a browser
# * The links appear in the last 2 columns of the dataframe.
# * TCIA links display the individual series described in each row.
# * IDC links display the entire study (all scans from that time point).
# * IDC links may not work if they haven't mirrored the series from TCIA, yet.
# * This function only works with fully public datasets (no limited-access data).
# * Optionally accepts a csv_filename parameter if you'd like to export a CSV file.

# %% [markdown]
# # 6. Other Functions

# %% [markdown]
# ## setApiUrl
#
# **Params: (endpoint, api_url)**
#
# * Checks for valid security tokens where needed
# * Because it is called by other functions to select base URL, ***<font color='red'>please do NOT use this function</font>***.
# * ***Note: Nearly all functions allow you to specify **api_url** as a query parameter.  This allows you to specify if you'd like to access restricted collections or the [National Lung Screening Trial (NLST)](https://doi.org/10.7937/TCIA.HMQ8-J677) collection, which lives on a separate server due to its size (>26,000 patients!).  We'll provide examples to show how this works later in the notebook.***

# %% [markdown]
# ## manifestToList
#
# **Params: (manifest)**
#
# * Ingests a TCIA manifest file and removes header
# * Returns a list of series UIDs
# * Because it is primarily a helper function used by downloadSeries() and makeSeriesReport(), ***<font color='red'>please do NOT use this function</font>***.

# %% [markdown]
# ## getToken
# **Params: (user = "", pw = "", api_url = "")**
#
# * Retrieves security token to access APIs that require authorization
# * Provides interactive prompts for user/pw if they're not specified as parameters
# * Uses getToken() for querying restricted collections with "Search API"
# * Uses getToken(api_url = "nlst") for "Advanced API" queries of National Lung Screening Trial
# * Sets expiration time for tokens (2 hours from creation)

# %%
nbia.getToken()

# %% [markdown]
# ## refreshToken
#
# **Params: (api_url = "")**
#
# * Refreshes security token to extend access time for APIs that require authorization
# * Must first use getToken() to create a token
# * Because it is primarily used by getToken() to keep the login seesion alive, ***<font color='red'>please do NOT use this function</font>***.

# %% [markdown]
# ## logoutToken
#
# **Params: (api_url = "")**
#
# * Logs out of a security token for APIs that require authorization
# * Must first use getToken() to create a token

# %%
nbia.logoutToken()

# %% [markdown]
# ## makeCredentialFile
# **Params: (user = "", pw = "")**
#
# * Creates a credential file to use with NBIA Data Retriever
# * Provides interactive prompts for user/pw if they're not specified as parameters
# * ***Note: A credential file is a text file that passes the user's credentials in the following format:***
#     * userName = YourUserName
#     * passWord = YourPassword
#     * *Both parameters are case-sensitive.*
# * Users are encouraged to take a look at the file being generated.
# * Documentation at https://wiki.cancerimagingarchive.net/x/2QKPBQ and notebook at https://github.com/kirbyju/TCIA_Notebooks/blob/main/TCIA_Linux_Data_Retriever_App.ipynb.

# %%
nbia.makeCredentialFile()

# %% [markdown]
# ## makeSeriesReport
#
# **Params: (series_data, input_type = "", format = "", filename = None, api_url = "")**
#
# * Ingests JSON output from any function that returns series-level data and creates summary report
# * Specify input_type = "manifest" to ingest a *.TCIA manifest file or "list" for a python list of UIDs.
# * If input_type = "manifest" or "list" and there are series UIDs that are restricted, you must call getToken() with a user ID that has access to all UIDs before calling this function.
# * Specifying api_url is only necessary if you are using input_type = "manifest" or "list" with NLST data (e.g. api_url = "nlst").
# * Specify format = "var" to return the report values as a dictionary.
# * Access variables example after saving function output to report_data: subjects = report_data["subjects"].
# * Specify format = "file" to save the report to a file.
# * Specify a filename parameter to set a filename if you don't want the default filename.

# %%
data = nbia.getSeries(collection = "CPTAC-SAR", patientId = "", studyUid = "", seriesUid = "",
                    modality = "", bodyPart = "", manufacturer = "", manufacturerModel = "", format = "df")
nbia.makeSeriesReport(data)

# %%
data = nbia.getSharedCart(name = "nbia-49121659384603347")
nbia.makeSeriesReport(data)

# %%
manifest = requests.get("https://wiki.cancerimagingarchive.net/download/attachments/22512757/doiJNLP-Fo0H1NtD.tcia?version=1&modificationDate=1534787017928&api=v2")
with open('RIDER_Breast_MRI.tcia', 'wb') as f:
    f.write(manifest.content)
nbia.makeSeriesReport("RIDER_Breast_MRI.tcia", input_type = "manifest")

# %% [markdown]
# We can also use other parameters to make the report in the format we want.

# %%
data = nbia.getSharedCart(name = "nbia-49121659384603347")
nbia.makeSeriesReport(data, format = "file", filename = "MyCart.txt")

# %%
data = nbia.getSharedCart(name = "nbia-49121659384603347")
nbia.makeSeriesReport(data, format = "var")

# %% [markdown]
# # Acknowledgements
# TCIA is funded by the [Cancer Imaging Program (CIP)](https://imaging.cancer.gov/), a part of the United States [National Cancer Institute (NCI)](https://www.cancer.gov/).  It is managed by the [Frederick National Laboratory for Cancer Research (FNLCR)](https://frederick.cancer.gov/) and hosted by the [University of Arkansas for Medical Sciences (UAMS)](https://www.uams.edu/)
#
# This notebook was created by [Justin Kirby](https://www.linkedin.com/in/justinkirby82/) and [Adam Li](https://www.linkedin.com/in/adam-l-713885121). If you leverage this notebook or any TCIA datasets in your work, please be sure to comply with the [TCIA Data Usage Policy](https://wiki.cancerimagingarchive.net/x/c4hF). In particular, make sure to cite the DOI(s) for the specific TCIA datasets you used in addition to the following paper!
#
# # TCIA Citation
#
# Clark, K., Vendt, B., Smith, K., Freymann, J., Kirby, J., Koppel, P., Moore, S., Phillips, S., Maffitt, D., Pringle, M., Tarbox, L., & Prior, F. (2013). The Cancer Imaging Archive (TCIA): Maintaining and Operating a Public Information Repository. Journal of Digital Imaging, 26(6), 1045–1057. https://doi.org/10.1007/s10278-013-9622-7
